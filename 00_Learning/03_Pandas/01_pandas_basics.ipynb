# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
file_path = "../../Datasets_Provided/Churn Prdiction Data/churn-bigml-80.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.tail(3)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2663                      0              231.1               57
# 2664                      0              180.8              109
# 2665                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2663             39.29              153.4               55             13.04
# 2664             30.74              288.8               58             24.55
# 2665             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# ...

# %%
df[["Total day minutes", "Churn"]]
# Out:
#       Total day minutes  Churn
# 0                 265.1  False
# 1                 161.6  False
# 2                 243.4  False
# 3                 299.4  False
# 4                 166.7  False
# ...                 ...    ...
# 2661              134.7  False
# 2662              156.2  False
# 2663              231.1  False
# 2664              180.8  False
# 2665              234.4  False
#
# [2666 rows x 2 columns]

# %%
df["State"].nunique()
# Out:
# 51

# %%
churned_customers = df[df["Churn"] == True]

# %%
churned_customers.head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 18    CO              77        408                 No              No
# 28    AZ              12        408                 No              No
# 35    MD             135        408                Yes             Yes
# 45    WY              87        415                 No              No
# 48    CO             121        408                 No             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 18                      0               62.4               89
# 28                      0              249.6              118
# 35                     41              173.1               85
# 45                      0              151.0               83
# 48                     30              198.4              129
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 18             10.61              169.9              121             14.44
# ...

# %%
churned_customers.shape
# Out:
# (388, 20)

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
df[[
    "Account length",
    "Total day minutes",
    "Customer service calls"
]].describe()
# Out:
#        Account length  Total day minutes  Customer service calls
# count     2666.000000         2666.00000             2666.000000
# mean       100.620405          179.48162                1.562641
# std         39.563974           54.21035                1.311236
# min          1.000000            0.00000                0.000000
# 25%         73.000000          143.40000                1.000000
# 50%        100.000000          179.95000                1.000000
# 75%        127.000000          215.90000                2.000000
# max        243.000000          350.80000                9.000000

# %%
high_day_usage = df[df["Total day minutes"] > 200]

high_day_usage.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 2                      0              243.4              114
# 3                      0              299.4               71
# 5                      0              223.4               98
# 6                     24              218.2               88
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
high_day_usage.shape[0]
# Out:
# 947

# %%
.shape       # (rows, columns)
.shape[0]    # only rows
.shape[1]    # only columns

# %%
high_usage_churned = df[
    (df["Total day minutes"] > 200) &
    (df["Churn"] == True)
]

high_usage_churned.head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 28    AZ              12        408                 No              No
# 64    DC              82        415                 No              No
# 71    TX             106        510                 No              No
# 75    NJ             128        415                 No              No
# 82    MS             120        408                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 28                      0              249.6              118
# 64                      0              300.3              109
# 71                      0              210.6               96
# 75                      0              237.9              125
# 82                      0              212.1              131
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 28             42.43              252.4              119             21.45
# ...

# %%
df[
    (df["Customer service calls"] >= 4) |
    (df["Churn"])
]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 12      IA              62        415                 No              No
# 18      CO              77        408                 No              No
# 28      AZ              12        408                 No              No
# 35      MD             135        408                Yes             Yes
# 45      WY              87        415                 No              No
# ...    ...             ...        ...                ...             ...
# 2643    OK             172        408                 No              No
# 2645    VT             100        408                Yes              No
# 2656    GA             122        510                Yes              No
# 2657    MD              62        408                 No              No
# 2658    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.sort_values(
    by="Total day minutes",
    ascending=False
).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 296     CO             154        415                 No              No
# 780     NY              64        415                Yes              No
# 2087    OH             115        510                Yes              No
# 128     OH              83        415                 No              No
# 485     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 296                       0              350.8               75
# 780                       0              346.8               55
# 2087                      0              345.3               81
# 128                       0              337.4              120
# 485                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
sorted_df = df.sort_values(
    by="Total day minutes",
    ascending=False
)
